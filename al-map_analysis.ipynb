# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Create the path to load the file
map_data_path = Path("Resources/merged_data.csv")

# Store the data into a dataframe
map_df = pd.read_csv(map_data_path, encoding="ISO-8859-1")
map_df.head()
# Out:
#                 name gender   teacher ethnicity sped  lep   ed   gt dyslexia  \
# 0         Molly Mora      F     Kirby         A  NaN  NaN  NaN  NaN      NaN
# 1      Kennedy Black      F     Gates         H  NaN    0    F  NaN      NaN
# 2     Nikolai Warren      M     Gates         A  NaN   M5  NaN  NaN      NaN
# 3        Efrain Meza      M  Lawrence         W  NaN  ESL    F  NaN      NaN
# 4  Valentino Houston      M     Kirby         W  NaN  NaN  NaN    Y      NaN
#
#    fa_16  ...  sp_20  fa_20  wi_21  sp_21  fa_21  wi_22  sp_22  fa_22  wi_23  \
# 0    NaN  ...    NaN  209.0  208.0  215.0  220.0  227.0  227.0  228.0  228.0
# 1    NaN  ...    NaN  194.0  198.0  207.0  206.0  210.0  211.0  216.0  216.0
# 2    NaN  ...    NaN  217.0  216.0  221.0  228.0  229.0  231.0  225.0  236.0
# 3    NaN  ...    NaN  184.0  197.0  201.0  192.0  211.0  216.0  213.0  222.0
# 4    NaN  ...    NaN  214.0  228.0  236.0  230.0  239.0  244.0  233.0  235.0
#
#    sp_23
# 0  233.0
# 1  215.0
# 2  240.0
# 3  219.0
# 4  246.0
#
# [5 rows x 28 columns]

# %%
# Check the column names 
map_df.columns
# Out:
# Index(['name', 'gender', 'teacher', 'ethnicity', 'sped', 'lep', 'ed', 'gt',
#        'dyslexia', 'fa_16', 'wi_17', 'sp_17', 'wi_18', 'sp_18', 'wi_19',
#        'sp_19', 'fa_19', 'wi_20', 'sp_20', 'fa_20', 'wi_21', 'sp_21', 'fa_21',
#        'wi_22', 'sp_22', 'fa_22', 'wi_23', 'sp_23'],
#       dtype='object')

# %%
# Rename all the columns to describe what the values are about 
renamed_columns = map_df.rename(columns={"fa_16":"fall_2016",
                                        "wi_17":"winter_2017",
                                        "sp_17":"spring_2017",
                                        "wi_18":"winter_2018",
                                        "sp_18":"spring_2018",
                                        "wi_19":"winter_2019",
                                        "sp_19":"spring_2019",
                                        "fa_19":"fall_2019",
                                        "wi_20":"winter_2020",
                                        "sp_20":"spring_2020",
                                        "fa_20":"fall_2020",
                                        "wi_21":"winter_2021",
                                        "sp_21":"spring_2021",
                                        "fa_21":"fall_2021",
                                        "wi_22":"winter_2022",
                                        "sp_22":"spring_2022",
                                        "fa_22":"fall_2022",
                                        "wi_23":"winter_2023",
                                        "wi_23":"winter_2023",
                                        "sp_23":"spring_2023"});

map_df = renamed_columns
map_df.head()
# Out:
#                 name gender   teacher ethnicity sped  lep   ed   gt dyslexia  \
# 0         Molly Mora      F     Kirby         A  NaN  NaN  NaN  NaN      NaN
# 1      Kennedy Black      F     Gates         H  NaN    0    F  NaN      NaN
# 2     Nikolai Warren      M     Gates         A  NaN   M5  NaN  NaN      NaN
# 3        Efrain Meza      M  Lawrence         W  NaN  ESL    F  NaN      NaN
# 4  Valentino Houston      M     Kirby         W  NaN  NaN  NaN    Y      NaN
#
#    fall_2016  ...  spring_2020  fall_2020  winter_2021  spring_2021  \
# 0        NaN  ...          NaN      209.0        208.0        215.0
# 1        NaN  ...          NaN      194.0        198.0        207.0
# 2        NaN  ...          NaN      217.0        216.0        221.0
# 3        NaN  ...          NaN      184.0        197.0        201.0
# 4        NaN  ...          NaN      214.0        228.0        236.0
#
#    fall_2021  winter_2022  spring_2022  fall_2022  winter_2023  spring_2023
# 0      220.0        227.0        227.0      228.0        228.0        233.0
# 1      206.0        210.0        211.0      216.0        216.0        215.0
# 2      228.0        229.0        231.0      225.0        236.0        240.0
# 3      192.0        211.0        216.0      213.0        222.0        219.0
# 4      230.0        239.0        244.0      233.0        235.0        246.0
#
# [5 rows x 28 columns]

# %%
# Rename all the columns to describe what the values are about 
renamed_columns = map_df.rename(columns={"fall_2016":"fall_2016_scores",
                                        "winter_2017":"winter_2017_scores",
                                        "spring_2017":"spring_2017_scores",
                                        "winter_2018":"winter_2018_scores",
                                        "spring_2018":"spring_2018_scores",
                                        "winter_2019":"winter_2019_scores",
                                        "spring_2019":"spring_2019_scores",
                                        "fall_2019":"fall_2019_scores",
                                        "winter_2020":"winter_2020_scores",
                                        "spring_2020":"spring_2020_scores",
                                        "fall_2020":"fall_2020_scores",
                                        "winter_2021":"winter_2021_scores",
                                        "spring_2021":"spring_2021_scores",
                                        "fall_2021":"fall_2021_scores",
                                        "winter_2022":"winter_2022_scores",
                                        "spring_2022":"spring_2022_scores",
                                        "fall_2022":"fall_2022_scores",
                                        "winter_2023":"winter_2023_scores",
                                        "winter_2023":"winter_2023_scores",
                                        "spring_2023":"spring_2023_scores"});

map_df = renamed_columns
map_df.head()
# Out:
#                 name gender   teacher ethnicity sped  lep   ed   gt dyslexia  \
# 0         Molly Mora      F     Kirby         A  NaN  NaN  NaN  NaN      NaN
# 1      Kennedy Black      F     Gates         H  NaN    0    F  NaN      NaN
# 2     Nikolai Warren      M     Gates         A  NaN   M5  NaN  NaN      NaN
# 3        Efrain Meza      M  Lawrence         W  NaN  ESL    F  NaN      NaN
# 4  Valentino Houston      M     Kirby         W  NaN  NaN  NaN    Y      NaN
#
#    fall_2016_scores  ...  spring_2020_scores  fall_2020_scores  \
# 0               NaN  ...                 NaN             209.0
# 1               NaN  ...                 NaN             194.0
# 2               NaN  ...                 NaN             217.0
# 3               NaN  ...                 NaN             184.0
# 4               NaN  ...                 NaN             214.0
#
#    winter_2021_scores  spring_2021_scores  fall_2021_scores  \
# 0               208.0               215.0             220.0
# 1               198.0               207.0             206.0
# 2               216.0               221.0             228.0
# 3               197.0               201.0             192.0
# 4               228.0               236.0             230.0
#
#    winter_2022_scores  spring_2022_scores  fall_2022_scores  \
# 0               227.0               227.0             228.0
# 1               210.0               211.0             216.0
# 2               229.0               231.0             225.0
# 3               211.0               216.0             213.0
# 4               239.0               244.0             233.0
#
#    winter_2023_scores  spring_2023_scores
# 0               228.0               233.0
# 1               216.0               215.0
# 2               236.0               240.0
# 3               222.0               219.0
# 4               235.0               246.0
#
# [5 rows x 28 columns]

# %%
# Determine where there are gaps in our data
# Extreme gaps include winter_2017_scores and spring_2020_scores
map_df.count()
# Out:
# name                  244
# gender                244
# teacher               244
# ethnicity             244
# sped                   36
# lep                   141
# ed                    161
# gt                     48
# dyslexia               25
# fall_2016_scores       10
# winter_2017_scores      5
# spring_2017_scores     75
# winter_2018_scores    173
# spring_2018_scores    182
# winter_2019_scores    180
# spring_2019_scores    184
# fall_2019_scores      133
# winter_2020_scores    197
# spring_2020_scores      3
# fall_2020_scores      196
# winter_2021_scores    207
# spring_2021_scores    212
# fall_2021_scores      224
# winter_2022_scores    225
# spring_2022_scores    225
# fall_2022_scores      234
# winter_2023_scores    238
# spring_2023_scores    237
# dtype: int64

# %%
school_year_22_23 = spring_2023_avg_by_teacher = map_df.groupby(["teacher"])["fall_2022_scores","winter_2023_scores","spring_2023_scores"].mean()
school_year_22_23.head()

school_year_22_23_df = pd.DataFrame(school_year_22_23)
school_year_22_23_df.head()
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\2561886519.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   school_year_22_23 = spring_2023_avg_by_teacher = map_df.groupby(["teacher"])["fall_2022_scores","winter_2023_scores","spring_2023_scores"].mean()
#           fall_2022_scores  winter_2023_scores  spring_2023_scores
# teacher
# Gates           211.615385          215.850000          217.710526
# Kirby           227.945652          231.684783          238.921348
# Lawrence        211.223881          215.926471          221.521739
# Paulson         207.972222          215.763158          218.170732

# %%
school_year_22_23_df.plot(kind="bar",figsize=(10,6))
plt.title("Average MAP Scores by Teacher for the 2022-2023 School Year")
plt.xlabel("6th Grade Math Teacher")
plt.ylabel("Average Math MAP Scores")
plt.legend(["Fall 2022", "Winter 2023", "Spring 2023"])
plt.show()

# %%
# Transpose the DataFrame
school_year_22_23_df = school_year_22_23_df.transpose()

# Plot the line graph
school_year_22_23_df.plot(kind="line",figsize=(10,6))
plt.title("Average MAP Scores by Teacher in 2022-2023 School Year")
plt.xlabel("Testing Period")
plt.ylabel("Average Math MAP Scores")
plt.legend(title="Teacher", loc="upper left")
plt.show()

# %%
spring_2023_avg_by_teacher = map_df.groupby(["teacher"])["spring_2023_scores"].mean()
spring_2023_avg_by_teacher.head()
# Out:
# teacher
# Gates       217.710526
# Kirby       238.921348
# Lawrence    221.521739
# Paulson     218.170732
# Name: spring_2023_scores, dtype: float64

# %%
avg_scores = map_df.groupby(["teacher"])["fall_2016_scores",
                                        "winter_2017_scores",
                                        "spring_2017_scores",
                                        "winter_2018_scores",
                                        "spring_2018_scores",
                                        "winter_2019_scores",
                                        "spring_2019_scores",
                                        "fall_2019_scores",
                                        "winter_2020_scores",
                                        "spring_2020_scores",
                                        "fall_2020_scores",
                                        "winter_2021_scores",
                                        "spring_2021_scores",
                                        "fall_2021_scores",
                                        "winter_2022_scores",
                                        "spring_2022_scores",
                                        "fall_2022_scores",
                                        "winter_2023_scores",
                                        "fall_2022_scores",
                                        "winter_2023_scores",
                                        "spring_2023_scores"].mean()
avg_scores.head()

avg_scores_df = pd.DataFrame(avg_scores)
avg_scores_df.head()
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\2422005588.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_scores = map_df.groupby(["teacher"])["fall_2016_scores",
#           fall_2016_scores  winter_2017_scores  spring_2017_scores  \
# teacher
# Gates                  NaN                 NaN          164.571429
# Kirby           149.000000                 NaN          178.090909
# Lawrence        131.333333               149.0          158.666667
# Paulson         138.800000               154.5          166.555556
#
#           winter_2018_scores  spring_2018_scores  winter_2019_scores  \
# teacher
# Gates             170.482759          183.218750          178.818182
# Kirby             181.571429          197.611111          193.072464
# Lawrence          164.795455          177.851064          176.448980
# Paulson           168.133333          179.419355          180.758621
#
#           spring_2019_scores  fall_2019_scores  winter_2020_scores  \
# teacher
# Gates             188.030303        183.931034          194.861111
# Kirby             201.416667        193.933333          207.232877
# Lawrence          187.812500        183.239130          192.142857
# Paulson           186.645161        186.035714          194.500000
#
#           spring_2020_scores  ...  winter_2021_scores  spring_2021_scores  \
# teacher                       ...
# Gates                    NaN  ...          201.171429          205.472222
# Kirby             210.333333  ...          216.592593          221.292683
# Lawrence                 NaN  ...          197.827586          203.400000
# Paulson                  NaN  ...          201.363636          203.794118
#
#           fall_2021_scores  winter_2022_scores  spring_2022_scores  \
# teacher
# Gates           203.027027          211.216216          215.945946
# Kirby           221.430233          228.091954          234.218391
# Lawrence        201.400000          209.227273          212.439394
# Paulson         204.805556          209.342857          214.085714
#
#           fall_2022_scores  winter_2023_scores  fall_2022_scores  \
# teacher
# Gates           211.615385          215.850000        211.615385
# Kirby           227.945652          231.684783        227.945652
# Lawrence        211.223881          215.926471        211.223881
# Paulson         207.972222          215.763158        207.972222
#
#           winter_2023_scores  spring_2023_scores
# teacher
# Gates             215.850000          217.710526
# Kirby             231.684783          238.921348
# Lawrence          215.926471          221.521739
# Paulson           215.763158          218.170732
#
# [4 rows x 21 columns]

# %%
# Transpose the DataFrame
avg_scores_df = avg_scores_df.transpose()

# Plot the line graph
avg_scores_df.plot(kind="line",figsize=(10,6))
plt.title("Average MAP Scores by Teacher per Year")
plt.xlabel("Years")
plt.ylabel("Average Math MAP Scores")
plt.legend(title="Teacher", loc="upper left")
plt.show()

# %%
before_after_covid = map_df.groupby(["teacher"])[
                                        "fall_2019_scores",
                                        "winter_2020_scores",
                                        "spring_2020_scores",
                                        "fall_2020_scores",
                                        "winter_2021_scores",
                                        "spring_2021_scores"
                                        ].mean()
before_after_covid.head()

before_after_covid_df = pd.DataFrame(before_after_covid)
before_after_covid_df.head()
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\3390409190.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   before_after_covid = map_df.groupby(["teacher"])[
#           fall_2019_scores  winter_2020_scores  spring_2020_scores  \
# teacher
# Gates           183.931034          194.861111                 NaN
# Kirby           193.933333          207.232877          210.333333
# Lawrence        183.239130          192.142857                 NaN
# Paulson         186.035714          194.500000                 NaN
#
#           fall_2020_scores  winter_2021_scores  spring_2021_scores
# teacher
# Gates           195.588235          201.171429          205.472222
# Kirby           210.638889          216.592593          221.292683
# Lawrence        196.241379          197.827586          203.400000
# Paulson         197.031250          201.363636          203.794118

# %%
# Transpose the DataFrame
before_after_covid_df = before_after_covid_df.transpose()

# Plot the line graph 
before_after_covid_df.plot(kind="line",figsize=(10,6))
plt.title("Average MAP Scores by Teacher per Year Before & After COVID")
plt.xlabel("Years")
plt.ylabel("Average Math MAP Scores")
plt.legend(title="Teacher", loc="upper left")
plt.show()

# %%
before_after_covid_df.head()
# Out:
# teacher                  Gates       Kirby    Lawrence     Paulson
# fall_2019_scores    183.931034  193.933333  183.239130  186.035714
# winter_2020_scores  194.861111  207.232877  192.142857  194.500000
# spring_2020_scores         NaN  210.333333         NaN         NaN
# fall_2020_scores    195.588235  210.638889  196.241379  197.031250
# winter_2021_scores  201.171429  216.592593  197.827586  201.363636

# %%
avg_scores.head()
# Out:
#           fall_2016_scores  winter_2017_scores  spring_2017_scores  \
# teacher
# Gates                  NaN                 NaN          164.571429
# Kirby           149.000000                 NaN          178.090909
# Lawrence        131.333333               149.0          158.666667
# Paulson         138.800000               154.5          166.555556
#
#           winter_2018_scores  spring_2018_scores  winter_2019_scores  \
# teacher
# Gates             170.482759          183.218750          178.818182
# Kirby             181.571429          197.611111          193.072464
# Lawrence          164.795455          177.851064          176.448980
# Paulson           168.133333          179.419355          180.758621
#
#           spring_2019_scores  fall_2019_scores  winter_2020_scores  \
# teacher
# Gates             188.030303        183.931034          194.861111
# Kirby             201.416667        193.933333          207.232877
# Lawrence          187.812500        183.239130          192.142857
# Paulson           186.645161        186.035714          194.500000
#
#           spring_2020_scores  ...  winter_2021_scores  spring_2021_scores  \
# teacher                       ...
# Gates                    NaN  ...          201.171429          205.472222
# Kirby             210.333333  ...          216.592593          221.292683
# Lawrence                 NaN  ...          197.827586          203.400000
# Paulson                  NaN  ...          201.363636          203.794118
#
#           fall_2021_scores  winter_2022_scores  spring_2022_scores  \
# teacher
# Gates           203.027027          211.216216          215.945946
# Kirby           221.430233          228.091954          234.218391
# Lawrence        201.400000          209.227273          212.439394
# Paulson         204.805556          209.342857          214.085714
#
#           fall_2022_scores  winter_2023_scores  fall_2022_scores  \
# teacher
# Gates           211.615385          215.850000        211.615385
# Kirby           227.945652          231.684783        227.945652
# Lawrence        211.223881          215.926471        211.223881
# Paulson         207.972222          215.763158        207.972222
#
#           winter_2023_scores  spring_2023_scores
# teacher
# Gates             215.850000          217.710526
# Kirby             231.684783          238.921348
# Lawrence          215.926471          221.521739
# Paulson           215.763158          218.170732
#
# [4 rows x 21 columns]

# %%
students_19_20_school_year = map_df.groupby(["gender"])["fall_2019_scores","winter_2019_scores","spring_2020_scores"].mean()
students_19_20_school_year
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\273849878.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   students_19_20_school_year = map_df.groupby(["gender"])["fall_2019_scores","winter_2019_scores","spring_2020_scores"].mean()
#         fall_2019_scores  winter_2019_scores  spring_2020_scores
# gender
# F             185.939394          182.594937                 NaN
# M             186.835821          185.009901          210.333333

# %%
# Create a DataFrame to represent 2019-2020 School Year Results for 3rd Grade Students
students_19_20_school_year_df = pd.DataFrame(students_19_20_school_year)

# Plot the results in a Bar Graph 
# Only a few male students took the Spring 2020 MAP test. Should answer this question "Why did kiddos take the Spring 2020 test" or "How did they take it if school wasn't in session during this time?"
students_19_20_school_year_df.plot(kind="bar",figsize=(10,6))
plt.title("Average MAP Scores for 3rd Grade Students in 2019-2020 School Year")
plt.xlabel("Gender")
plt.ylabel("Average Math MAP Scores")
plt.legend(["Fall 2019", "Winter 2019", "Spring 2020"])
plt.show()

# %%
students_20_21_school_year = map_df.groupby(["gender"])["fall_2020_scores","winter_2020_scores","spring_2021_scores"].mean()
students_20_21_school_year
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\4281090794.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   students_20_21_school_year = map_df.groupby(["gender"])["fall_2020_scores","winter_2020_scores","spring_2021_scores"].mean()
#         fall_2020_scores  winter_2020_scores  spring_2021_scores
# gender
# F             199.868132          196.956044          208.440000
# M             203.000000          200.037736          212.785714

# %%
# Create a DataFrame to represent 2019-2020 School Year Results for 3rd Grade Students
students_20_21_school_year_df = pd.DataFrame(students_20_21_school_year)

# Plot the results in a Bar Graph 
students_20_21_school_year_df.plot(kind="bar",figsize=(10,6))
plt.title("Average MAP Scores for 4th Grade Students in 2020-2021 School Year")
plt.xlabel("Gender")
plt.ylabel("Average Math MAP Scores")
plt.legend(["Fall 2020", "Winter 2020", "Spring 2021"])
plt.show()

# %%
students_21_22_school_year = map_df.groupby(["gender"])["fall_2021_scores","winter_2021_scores","spring_2021_scores"].mean()
students_21_22_school_year
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\364364452.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   students_21_22_school_year = map_df.groupby(["gender"])["fall_2021_scores","winter_2021_scores","spring_2021_scores"].mean()
#         fall_2021_scores  winter_2021_scores  spring_2021_scores
# gender
# F             208.822430          204.010526          208.440000
# M             210.897436          208.241071          212.785714

# %%
# Create a DataFrame to represent 2019-2020 School Year Results for 3rd Grade Students
students_21_22_school_year_df = pd.DataFrame(students_21_22_school_year)

# Plot the results in a Bar Graph 
students_21_22_school_year_df.plot(kind="bar",figsize=(10,6))
plt.title("Average MAP Scores for 5th Grade Students in 2021-2022 School Year")
plt.xlabel("Gender")
plt.ylabel("Average Math MAP Scores")
plt.legend(["Fall 2021", "Winter 2021", "Spring 2022"])
plt.show()

# %%
students_22_23_school_year = map_df.groupby(["gender"])["fall_2022_scores","winter_2022_scores","spring_2023_scores"].mean()
students_22_23_school_year
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_38168\1978071673.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   students_22_23_school_year = map_df.groupby(["gender"])["fall_2022_scores","winter_2022_scores","spring_2023_scores"].mean()
#         fall_2022_scores  winter_2022_scores  spring_2023_scores
# gender
# F             215.892857          215.166667          226.873874
# M             218.713115          218.435897          226.857143

# %%
# Create a DataFrame to represent 2019-2020 School Year Results for 3rd Grade Students
students_22_23_school_year_df = pd.DataFrame(students_22_23_school_year)

# Plot the results in a Bar Graph 
students_22_23_school_year_df.plot(kind="bar",figsize=(10,6))
plt.title("Average MAP Scores for 6th Grade Students in 2021-2022 School Year")
plt.xlabel("Gender")
plt.ylabel("Average Math MAP Scores")
plt.legend(["Fall 2022", "Winter 2022", "Spring 2023"])
plt.show()
